# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshikka03/assessment/blob/main/emplyoee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

actual = [10, 20, 30, 40, 50]
predicted = [12, 18, 33, 37, 52]

a = np.array(actual)
p = np.array(predicted)

# Standard deviation
print("Standard Deviation:", np.std(a))

# Mean Squared Error (MSE)
mse = np.mean((a - p) ** 2)
print("Mean Squared Error:", mse)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Standard Deviation: 14.142135623730951
# Mean Squared Error: 6.0
# Root Mean Squared Error: 2.449489742783178

# %%
import numpy as np
import pandas as pd

list= [1,2,3,4,5]
array_one= np.array(list)
print(array_one)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np
import pandas as pd

# %%
np.mean(array_one)
# Out:
# np.float64(3.0)

# %%
np.absolute(array_one)
# Out:
# array([1, 2, 3, 4, 5])

# %%
df = pd.read_csv('/content/employee.csv', encoding='latin-1')
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-22-739056489.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/employee_data.csv', encoding='latin-1')
#       2 display(df)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
data = {
    'A': [-0.1, 0.2, 0.3],
    'B': [-0.5, -0.3, -0.35],
    'C': [-1.0, -0.5, -0.56],
    'D': [5, 5, 5],
    'F': [3, 3, 3]
}

df = pd.DataFrame(data)
print(df)

mean_values = df.mean()
print(mean_values)
# Out:
#      A     B     C  D  F
# 0 -0.1 -0.50 -1.00  5  3
# 1  0.2 -0.30 -0.50  5  3
# 2  0.3 -0.35 -0.56  5  3
# A    0.133333
# B   -0.383333
# C   -0.686667
# D    5.000000
# F    3.000000
# dtype: float64

# %%
import pandas as pd
import numpy as np

# Sample dataframe with datetime index
dates = pd.date_range('2013-01-01', periods=6)
df = pd.DataFrame(np.random.rand(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])

# Calculate mean for each row
row_means = df.mean(axis=1)
print(row_means)
# Out:
# 2013-01-01    0.736563
# 2013-01-02    0.315297
# 2013-01-03    0.472547
# 2013-01-04    0.468965
# 2013-01-05    0.521938
# 2013-01-06    0.433397
# Freq: D, dtype: float64

# %%
import pandas as pd
import numpy as np
# Create dates as index
dates = pd.date_range('2023-01-01', periods=6)

# Create a DataFrame with random numbers
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])

# Show the DataFrame
df
# Out:
#                    A         B         C         D
# 2023-01-01 -1.722331  0.737400 -0.702965 -0.918145
# 2023-01-02 -0.618354 -0.259548  0.138407 -0.760825
# 2023-01-03  0.649576 -1.094853  2.511285 -2.100131
# 2023-01-04 -2.163908  0.117817 -1.765666  0.535459
# 2023-01-05  0.231745  2.277726  1.593571 -0.198963
# 2023-01-06 -0.069958  1.527525 -0.584256  1.531440

# %%
df.mean()  # axis=0 by default
# Out:
# A   -0.615538
# B    0.551011
# C    0.198396
# D   -0.318527
# dtype: float64

# %%
df = pd.DataFrame(list)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df.mean(axis=1)  # axis=1 means "across columns"
# Out:
# 2023-01-01   -0.651510
# 2023-01-02   -0.375080
# 2023-01-03   -0.008531
# 2023-01-04   -0.819074
# 2023-01-05    0.976020
# 2023-01-06    0.601188
# Freq: D, dtype: float64

# %%
df['RowMean'] = df.mean(axis=1)
df
# Out:
#                    A         B         C         D   RowMean
# 2023-01-01 -1.722331  0.737400 -0.702965 -0.918145 -0.651510
# 2023-01-02 -0.618354 -0.259548  0.138407 -0.760825 -0.375080
# 2023-01-03  0.649576 -1.094853  2.511285 -2.100131 -0.008531
# 2023-01-04 -2.163908  0.117817 -1.765666  0.535459 -0.819074
# 2023-01-05  0.231745  2.277726  1.593571 -0.198963  0.976020
# 2023-01-06 -0.069958  1.527525 -0.584256  1.531440  0.601188

# %%
print("Max per column:\n", df.max())
print("Min per column:\n", df.min())
print("Standard deviation:\n", df.std())
print("Sum of each row:\n", df.sum(axis=1))
# Out:
# Max per column:
#  A          0.649576
# B          2.277726
# C          2.511285
# D          1.531440
# RowMean    0.976020
# dtype: float64
# Min per column:
#  A         -2.163908
# B         -1.094853
# C         -1.765666
# D         -2.100131
# RowMean   -0.819074
# dtype: float64
# Standard deviation:
#  A          1.117006
# B          1.226654
# C          1.586323
# D          1.256602
# RowMean    0.712371
# dtype: float64
# Sum of each row:
#  2023-01-01   -3.257550
# 2023-01-02   -1.875401
# 2023-01-03   -0.042654
# 2023-01-04   -4.095372
# 2023-01-05    4.880099
# 2023-01-06    3.005939
# Freq: D, dtype: float64

# %%
np.mean(array_one)
# Out:
# np.float64(3.0)

# %%
import os
print(os.listdir('/content/'))
# Out:
# ['.config', 'drive', 'sample_data']
